# %%
import numpy as np
import pandas as pd

filepath = r"C:\Users\Balraj\balraj_proj\Learning_Pandas\details1.csv"

df = pd.read_csv(filepath)
df
# Out:
#         name  marks  height             job coding game     salary country  \
# 0     kishan     95     175        youtuber     NO   NO        NaN   China
# 1  Aravindan     96     170        Robotics    Yes  YES   120000.0     USA
# 2     Mahesh     91     165  Data Scientist    Yes   NO   130000.0      UK
# 3   Santhosh     93     172         Richman     No  Yes   999999.0      UK
# 4   Sarvesha     78     175        Software    Yes   NO  1234500.0   India
#
#     language
# 0        NaN
# 1  Python,C#
# 2     "Java"
# 3        NaN
# 4     Python

# %%
# Update the entire 'Age' column with a scalar value
df['Age'] = 0
print(df)
# Out:
#         name  marks  height             job coding game     salary country  \
# 0     kishan     95     175        youtuber     NO   NO        NaN   China
# 1  Aravindan     96     170        Robotics    Yes  YES   120000.0     USA
# 2     Mahesh     91     165  Data Scientist    Yes   NO   130000.0      UK
# 3   Santhosh     93     172         Richman     No  Yes   999999.0      UK
# 4   Sarvesha     78     175        Software    Yes   NO  1234500.0   India
#
#     language  Age
# 0        NaN    0
# 1  Python,C#    0
# 2     "Java"    0
# 3        NaN    0
# 4     Python    0

# %%
df
# Out:
#         name  marks  height             job coding game     salary country  \
# 0     kishan     95     175        youtuber     NO   NO        NaN   China
# 1  Aravindan     96     170        Robotics    Yes  YES   120000.0     USA
# 2     Mahesh     91     165  Data Scientist    Yes   NO   130000.0      UK
# 3   Santhosh     93     172         Richman     No  Yes   999999.0      UK
# 4   Sarvesha     78     175        Software    Yes   NO  1234500.0   India
#
#     language  Age
# 0        NaN    0
# 1  Python,C#    0
# 2     "Java"    0
# 3        NaN    0
# 4     Python    0

# %%
#to get all the columns names
df.columns
# Out:
# Index(['name', 'marks', 'height', 'job', 'coding', 'game', 'salary', 'country',
#        'language', 'Age'],
#       dtype='object')

# %%
df.columns = ['name', 'marks', 'height', 'job', 'coding', 'play', 'salary', 'country',
       'languages', 'Age']

# %%
df.columns
# Out:
# Index(['name', 'marks', 'height', 'job', 'coding', 'play', 'salary', 'country',
#        'languages', 'Age'],
#       dtype='object')

# %%
df
# Out:
#         name  marks  height             job coding play     salary country  \
# 0     kishan     95     175        youtuber     NO   NO        NaN   China
# 1  Aravindan     96     170        Robotics    Yes  YES   120000.0     USA
# 2     Mahesh     91     165  Data Scientist    Yes   NO   130000.0      UK
# 3   Santhosh     93     172         Richman     No  Yes   999999.0      UK
# 4   Sarvesha     78     175        Software    Yes   NO  1234500.0   India
#
#    languages  Age
# 0        NaN    0
# 1  Python,C#    0
# 2     "Java"    0
# 3        NaN    0
# 4     Python    0

# %%
df.marks
# Out:
# 0    95
# 1    96
# 2    91
# 3    93
# 4    78
# Name: marks, dtype: int64

# %%
df["marks"]
# Out:
# 0    95
# 1    96
# 2    91
# 3    93
# 4    78
# Name: marks, dtype: int64

# %%
df.columns
# Out:
# Index(['name', 'marks', 'height', 'job', 'coding', 'play', 'salary', 'country',
#        'languages', 'Age'],
#       dtype='object')

# %%
#to change all columns into uppercase using list comprehension

df.columns = [col.upper() for col in df.columns]
df.columns
# Out:
# Index(['NAME', 'MARKS', 'HEIGHT', 'JOB', 'CODING', 'PLAY', 'SALARY', 'COUNTRY',
#        'LANGUAGES', 'AGE'],
#       dtype='object')

# %%
df
# Out:
#         NAME  MARKS  HEIGHT             JOB CODING PLAY     SALARY COUNTRY  \
# 0     kishan     95     175        youtuber     NO   NO        NaN   China
# 1  Aravindan     96     170        Robotics    Yes  YES   120000.0     USA
# 2     Mahesh     91     165  Data Scientist    Yes   NO   130000.0      UK
# 3   Santhosh     93     172         Richman     No  Yes   999999.0      UK
# 4   Sarvesha     78     175        Software    Yes   NO  1234500.0   India
#
#    LANGUAGES  AGE
# 0        NaN    0
# 1  Python,C#    0
# 2     "Java"    0
# 3        NaN    0
# 4     Python    0

# %%
df
# Out:
#         NAME  MARKS  HEIGHT             JOB CODING PLAY     SALARY COUNTRY  \
# 0     kishan     95     175        youtuber     NO   NO        NaN   China
# 1  Aravindan     96     170        Robotics    Yes  YES   120000.0     USA
# 2     Mahesh     91     165  Data Scientist    Yes   NO   130000.0      UK
# 3   Santhosh     93     172         Richman     No  Yes   999999.0      UK
# 4   Sarvesha     78     175        Software    Yes   NO  1234500.0   India
#
#    LANGUAGES  AGE
# 0        NaN    0
# 1  Python,C#    0
# 2     "Java"    0
# 3        NaN    0
# 4     Python    0

# %%
df.columns
# Out:
# Index(['NAME', 'MARKS', 'HEIGHT', 'JOB', 'CODING', 'PLAY', 'SALARY', 'COUNTRY',
#        'LANGUAGES', 'AGE'],
#       dtype='object')

# %%
#to rename a column name as inplace
df.rename(columns = {"MARKS": "MARKS OBTAINED"},inplace=True)

# %%
df
# Out:
#         NAME  MARKS OBTAINED  HEIGHT             JOB CODING PLAY     SALARY  \
# 0     kishan              95     175        youtuber     NO   NO        NaN
# 1  Aravindan              96     170        Robotics    Yes  YES   120000.0
# 2     Mahesh              91     165  Data Scientist    Yes   NO   130000.0
# 3   Santhosh              93     172         Richman     No  Yes   999999.0
# 4   Sarvesha              78     175        Software    Yes   NO  1234500.0
#
#   COUNTRY  LANGUAGES  AGE
# 0   China        NaN    0
# 1     USA  Python,C#    0
# 2      UK     "Java"    0
# 3      UK        NaN    0
# 4   India     Python    0

# %%
#to rename a column without inplace
df = df.rename(columns = {"MARKS OBTAINED":"MARKS_OBTAINED"})
df.columns
# Out:
# Index(['NAME', 'MARKS_OBTAINED', 'HEIGHT', 'JOB', 'CODING', 'PLAY', 'SALARY',
#        'COUNTRY', 'LANGUAGES', 'AGE'],
#       dtype='object')

# %%
df
# Out:
#         NAME  MARKS_OBTAINED  HEIGHT             JOB CODING PLAY     SALARY  \
# 0     kishan              95     175        youtuber     NO   NO        NaN
# 1  Aravindan              96     170        Robotics    Yes  YES   120000.0
# 2     Mahesh              91     165  Data Scientist    Yes   NO   130000.0
# 3   Santhosh              93     172         Richman     No  Yes   999999.0
# 4   Sarvesha              78     175        Software    Yes   NO  1234500.0
#
#   COUNTRY  LANGUAGES  AGE
# 0   China        NaN    0
# 1     USA  Python,C#    0
# 2      UK     "Java"    0
# 3      UK        NaN    0
# 4   India     Python    0

# %%
df
# Out:
#         NAME  MARKS_OBTAINED  HEIGHT             JOB CODING PLAY     SALARY  \
# 0     kishan              95     175        youtuber     NO   NO        NaN
# 1  Aravindan              96     170        Robotics    Yes  YES   120000.0
# 2     Mahesh              91     165  Data Scientist    Yes   NO   130000.0
# 3   Santhosh              93     172         Richman     No  Yes   999999.0
# 4   Sarvesha              78     175        Software    Yes   NO  1234500.0
#
#   COUNTRY  LANGUAGES  AGE  Height
# 0   China        NaN    0     NaN
# 1     USA  Python,C#    0     NaN
# 2      UK     "Java"    0   173.0
# 3      UK        NaN    0     NaN
# 4   India     Python    0     NaN

# %%
df.loc[2,"JOB"]
df.loc[2,"HEIGHT"] = 173
#df.loc[df['Name'] == 'Bob', 'Age'] = df['Age'] + 5

# %%
df
# Out:
#         NAME  MARKS_OBTAINED  HEIGHT             JOB CODING PLAY     SALARY  \
# 0     kishan              95     175        youtuber     NO   NO        NaN
# 1  Aravindan              96     170        Robotics    Yes  YES   120000.0
# 2     Mahesh              91     173  Data Scientist    Yes   NO   130000.0
# 3   Santhosh              93     172         Richman     No  Yes   999999.0
# 4   Sarvesha              78     175        Software    Yes   NO  1234500.0
#
#   COUNTRY  LANGUAGES  AGE  Height
# 0   China        NaN    0     NaN
# 1     USA  Python,C#    0     NaN
# 2      UK     "Java"    0   173.0
# 3      UK        NaN    0     NaN
# 4   India     Python    0     NaN

# %%
df
# Out:
#         NAME  MARKS_OBTAINED  HEIGHT             JOB CODING PLAY     SALARY  \
# 0     kishan              95     175        youtuber     NO   NO        NaN
# 1  Aravindan              96     170        Robotics    Yes  YES   120000.0
# 2     Mahesh              91     173  Data Scientist    Yes   NO   130000.0
# 3   Santhosh              93     172         Richman     No  Yes   999999.0
# 4   Sarvesha              78     175        Software    Yes   NO  1234500.0
#
#   COUNTRY  LANGUAGES  AGE  Height
# 0   China        NaN    0     NaN
# 1     USA  Python,C#    0     NaN
# 2      UK     "Java"    0   173.0
# 3      UK        NaN    0     NaN
# 4   India     Python    0     NaN

# %%
df.loc[df['NAME'] == 'Mahesh', 'AGE'] = df['AGE'] + 33

# %%
df
# Out:
#         NAME  MARKS_OBTAINED  HEIGHT             JOB CODING PLAY     SALARY  \
# 0     kishan              95     175        youtuber     NO   NO        NaN
# 1  Aravindan              96     170        Robotics    Yes  YES   120000.0
# 2     Mahesh              91     173  Data Scientist    Yes   NO   130000.0
# 3   Santhosh              93     172         Richman     No  Yes   999999.0
# 4   Sarvesha              78     175        Software    Yes   NO  1234500.0
#
#   COUNTRY  LANGUAGES  AGE  Height
# 0   China        NaN    0     NaN
# 1     USA  Python,C#    0     NaN
# 2      UK     "Java"   33   173.0
# 3      UK        NaN    0     NaN
# 4   India     Python    0     NaN

# %%
aa = df["NAME"]=="Mahesh"
aa
# Out:
# 0    False
# 1    False
# 2     True
# 3    False
# 4    False
# Name: NAME, dtype: bool

# %%
df.loc[aa]
# Out:
#      NAME  MARKS_OBTAINED  HEIGHT             JOB CODING PLAY    SALARY  \
# 2  Mahesh              91     173  Data Scientist    Yes   NO  130000.0
#
#   COUNTRY LANGUAGES  AGE  Height
# 2      UK    "Java"   33   173.0

# %%
df.loc[df["NAME"]=="Mahesh"]
# Out:
#      NAME  MARKS_OBTAINED  HEIGHT             JOB CODING PLAY    SALARY  \
# 2  Mahesh              91     173  Data Scientist    Yes   NO  130000.0
#
#   COUNTRY LANGUAGES  AGE  Height
# 2      UK    "Java"   33   173.0

# %%
print(df["NAME"]=="Mahesh")
# Out:
# 0    False
# 1    False
# 2     True
# 3    False
# 4    False
# Name: NAME, dtype: bool

# %%
print(len(df[df["NAME"]=="Mahesh1"]))
# Out:
# 0

# %%
df.loc[df["NAME"]=="Santhosh", "AGE"]=df["AGE"]+5

# %%
df
# Out:
#         NAME  MARKS_OBTAINED  HEIGHT             JOB CODING PLAY     SALARY  \
# 0     kishan              95     175        youtuber     NO   NO        NaN
# 1  Aravindan              96     170        Robotics    Yes  YES   120000.0
# 2     Mahesh              91     173  Data Scientist    Yes   NO   130000.0
# 3   Santhosh              93     172         Richman     No  Yes   999999.0
# 4   Sarvesha              78     175        Software    Yes   NO  1234500.0
#
#   COUNTRY  LANGUAGES  AGE  Height
# 0   China        NaN    0     NaN
# 1     USA  Python,C#    0     NaN
# 2      UK     "Java"   33   173.0
# 3      UK        NaN    5     NaN
# 4   India     Python    0     NaN

# %%
# Create a new column 'RESULT' based on 'MARKS to record as PASS if marks > 91 else FAIL'
df["RESULT"] = df["MARKS_OBTAINED"].apply(lambda x: "PASS" if x > 91 else "FAIL")
df
# Out:
#         NAME  MARKS_OBTAINED  HEIGHT             JOB CODING PLAY     SALARY  \
# 0     kishan              95     175        youtuber     NO   NO        NaN
# 1  Aravindan              96     170        Robotics    Yes  YES   120000.0
# 2     Mahesh              91     173  Data Scientist    Yes   NO   130000.0
# 3   Santhosh              93     172         Richman     No  Yes   999999.0
# 4   Sarvesha              78     175        Software    Yes   NO  1234500.0
#
#   COUNTRY  LANGUAGES  AGE  Height RESULT
# 0   China        NaN    0     NaN   PASS
# 1     USA  Python,C#    0     NaN   PASS
# 2      UK     "Java"   33   173.0   FAIL
# 3      UK        NaN    5     NaN   PASS
# 4   India     Python    0     NaN   FAIL

# %%
# Create a new column 'Double_Age' as twice the values of 'AGE'
df["DOUBLE_AGE"] = df["AGE"]*2
df
# Out:
#         NAME  MARKS_OBTAINED  HEIGHT             JOB CODING PLAY     SALARY  \
# 0     kishan              95     175        youtuber     NO   NO        NaN
# 1  Aravindan              96     170        Robotics    Yes  YES   120000.0
# 2     Mahesh              91     173  Data Scientist    Yes   NO   130000.0
# 3   Santhosh              93     172         Richman     No  Yes   999999.0
# 4   Sarvesha              78     175        Software    Yes   NO  1234500.0
#
#   COUNTRY  LANGUAGES  AGE  Height RESULT  DOUBLE_AGE
# 0   China        NaN    0     NaN   PASS           0
# 1     USA  Python,C#    0     NaN   PASS           0
# 2      UK     "Java"   33   173.0   FAIL          66
# 3      UK        NaN    5     NaN   PASS          10
# 4   India     Python    0     NaN   FAIL           0

# %%
#Updating Multiple Columns Simultaneously
df[['MARKS_OBTAINED', 'HEIGHT']] = df[['MARKS_OBTAINED', 'HEIGHT']] + 1

# %%
df
# Out:
#         NAME  MARKS_OBTAINED  HEIGHT             JOB CODING PLAY     SALARY  \
# 0     kishan              96     176        youtuber     NO   NO        NaN
# 1  Aravindan              97     171        Robotics    Yes  YES   120000.0
# 2     Mahesh              92     174  Data Scientist    Yes   NO   130000.0
# 3   Santhosh              94     173         Richman     No  Yes   999999.0
# 4   Sarvesha              79     176        Software    Yes   NO  1234500.0
#
#   COUNTRY  LANGUAGES  AGE  Height RESULT  DOUBLE_AGE
# 0   China        NaN    0     NaN   PASS           0
# 1     USA  Python,C#    0     NaN   PASS           0
# 2      UK     "Java"   33   173.0   FAIL          66
# 3      UK        NaN    5     NaN   PASS          10
# 4   India     Python    0     NaN   FAIL           0

# %%
df["AGE_CATAGORY"] = 0
df
# Out:
#         NAME  MARKS_OBTAINED  HEIGHT             JOB CODING PLAY     SALARY  \
# 0     kishan              96     176        youtuber     NO   NO        NaN
# 1  Aravindan              97     171        Robotics    Yes  YES   120000.0
# 2     Mahesh              92     174  Data Scientist    Yes   NO   130000.0
# 3   Santhosh              94     173         Richman     No  Yes   999999.0
# 4   Sarvesha              79     176        Software    Yes   NO  1234500.0
#
#   COUNTRY  LANGUAGES  AGE  Height RESULT  DOUBLE_AGE  AGE_CATAGORY
# 0   China        NaN    0     NaN   PASS           0             0
# 1     USA  Python,C#    0     NaN   PASS           0             0
# 2      UK     "Java"   33   173.0   FAIL          66             0
# 3      UK        NaN    5     NaN   PASS          10             0
# 4   India     Python    0     NaN   FAIL           0             0

# %%
# Convert the 'Age' column to string (which will be of type 'object' in pandas)
df['AGE_CATAGORY'] = df['AGE_CATAGORY'].astype(str)  # or astype('object')


df.loc[(df["MARKS_OBTAINED"]>=75) & (df["MARKS_OBTAINED"]<=80), "AGE_CATAGORY"] = "Middle-Aged"
df
# Out:
#         NAME  MARKS_OBTAINED  HEIGHT             JOB CODING PLAY     SALARY  \
# 0     kishan              96     176        youtuber     NO   NO        NaN
# 1  Aravindan              97     171        Robotics    Yes  YES   120000.0
# 2     Mahesh              92     174  Data Scientist    Yes   NO   130000.0
# 3   Santhosh              94     173         Richman     No  Yes   999999.0
# 4   Sarvesha              79     176        Software    Yes   NO  1234500.0
#
#   COUNTRY  LANGUAGES  AGE  Height RESULT  DOUBLE_AGE    AGE_CATAGORY
# 0   China        NaN    0     NaN   PASS           0  Senior Citizen
# 1     USA  Python,C#    0     NaN   PASS           0  Senior Citizen
# 2      UK     "Java"   33   173.0   FAIL          66  Senior Citizen
# 3      UK        NaN    5     NaN   PASS          10  Senior Citizen
# 4   India     Python    0     NaN   FAIL           0     Middle-Aged

# %%
df.loc[df["MARKS_OBTAINED"]>=93]
# Out:
#         NAME  MARKS_OBTAINED  HEIGHT       JOB CODING PLAY    SALARY COUNTRY  \
# 0     kishan              96     176  youtuber     NO   NO       NaN   China
# 1  Aravindan              97     171  Robotics    Yes  YES  120000.0     USA
# 3   Santhosh              94     173   Richman     No  Yes  999999.0      UK
#
#    LANGUAGES  AGE  Height RESULT  DOUBLE_AGE    AGE_CATAGORY
# 0        NaN    0     NaN   PASS           0  Senior Citizen
# 1  Python,C#    0     NaN   PASS           0  Senior Citizen
# 3        NaN    5     NaN   PASS          10  Senior Citizen

# %%
df.loc[df["MARKS_OBTAINED"]<=96]
# Out:
#        NAME  MARKS_OBTAINED  HEIGHT             JOB CODING PLAY     SALARY  \
# 0    kishan              96     176        youtuber     NO   NO        NaN
# 2    Mahesh              92     174  Data Scientist    Yes   NO   130000.0
# 3  Santhosh              94     173         Richman     No  Yes   999999.0
# 4  Sarvesha              79     176        Software    Yes   NO  1234500.0
#
#   COUNTRY LANGUAGES  AGE  Height RESULT  DOUBLE_AGE    AGE_CATAGORY
# 0   China       NaN    0     NaN   PASS           0  Senior Citizen
# 2      UK    "Java"   33   173.0   FAIL          66  Senior Citizen
# 3      UK       NaN    5     NaN   PASS          10  Senior Citizen
# 4   India    Python    0     NaN   FAIL           0     Middle-Aged

# %%
df.loc[(df["MARKS_OBTAINED"]>=94) & (df["MARKS_OBTAINED"]<=96),"AGE_CATAGORY"]= "Senior Aged"

# %%
df
# Out:
#         NAME  MARKS_OBTAINED  HEIGHT             JOB CODING PLAY     SALARY  \
# 0     kishan              96     176        youtuber     NO   NO        NaN
# 1  Aravindan              97     171        Robotics    Yes  YES   120000.0
# 2     Mahesh              92     174  Data Scientist    Yes   NO   130000.0
# 3   Santhosh              94     173         Richman     No  Yes   999999.0
# 4   Sarvesha              79     176        Software    Yes   NO  1234500.0
#
#   COUNTRY  LANGUAGES  AGE  Height RESULT  DOUBLE_AGE    AGE_CATAGORY
# 0   China        NaN    0     NaN   PASS           0     Senior Aged
# 1     USA  Python,C#    0     NaN   PASS           0  Senior Citizen
# 2      UK     "Java"   33   173.0   FAIL          66  Senior Citizen
# 3      UK        NaN    5     NaN   PASS          10     Senior Aged
# 4   India     Python    0     NaN   FAIL           0     Middle-Aged

# %%
df.to_csv("Update_columns.csv", index=False)
