# %%
import pandas as pd

filename = "C:\\Users\\Balraj\\balraj_proj\\Learning_Pandas\\ex_21102024\\row_updates.csv"
df = pd.read_csv(filename)

df.columns
# Out:
# Index(['NAME', 'MARKS_OBTAINED', 'HEIGHT', 'JOB', 'CODING', 'PLAY', 'SALARY',
#        'COUNTRY', 'LANGUAGES', 'AGE', 'Height', 'RESULT', 'DOUBLE_AGE',
#        'AGE_CATAGORY'],
#       dtype='object')

# %%
df
# Out:
#           NAME  MARKS_OBTAINED  HEIGHT             JOB CODING PLAY     SALARY  \
# 0          Ram              96     176        youtuber     NO   NO    13000.0
# 1       Arunan              97     171        Robotics    Yes  Yes   120000.0
# 2  Ambalavanan              92     174  Data Scientist    Yes   NO   130000.0
# 3  Swaminathan              94     173         Richman     No  Yes   999999.0
# 4        Kumar              79     176        Software    Yes   NO  1234500.0
#
#      COUNTRY  LANGUAGES  AGE  Height RESULT  DOUBLE_AGE    AGE_CATAGORY
# 0  Singapore    Unknown    0     0.0   PASS           0     Senior Aged
# 1        USA  Python,C#    0     0.0   PASS           0  Senior Citizen
# 2         UK       Java   33   173.0   FAIL          66  Senior Citizen
# 3         UK    Unknown    5     0.0   PASS          10     Senior Aged
# 4      India     Python    0     0.0   FAIL           0     Middle-Aged

# %%
df["EMAIL"] = ["ram@gmail.com","arunan@gmail.com","ambalavanan@gmail.com","swaminathan@gmail.com","kumar@gmail.com"]
df
# Out:
#           NAME  MARKS_OBTAINED  HEIGHT             JOB CODING PLAY     SALARY  \
# 0          Ram              96     176        youtuber     NO   NO    13000.0
# 1       Arunan              97     171        Robotics    Yes  Yes   120000.0
# 2  Ambalavanan              92     174  Data Scientist    Yes   NO   130000.0
# 3  Swaminathan              94     173         Richman     No  Yes   999999.0
# 4        Kumar              79     176        Software    Yes   NO  1234500.0
#
#      COUNTRY  LANGUAGES  AGE  Height RESULT  DOUBLE_AGE    AGE_CATAGORY  \
# 0  Singapore    Unknown    0     0.0   PASS           0     Senior Aged
# 1        USA  Python,C#    0     0.0   PASS           0  Senior Citizen
# 2         UK       Java   33   173.0   FAIL          66  Senior Citizen
# 3         UK    Unknown    5     0.0   PASS          10     Senior Aged
# 4      India     Python    0     0.0   FAIL           0     Middle-Aged
#
#                    EMAIL
# 0          ram@gmail.com
# ...

# %%
df = df.rename(columns = {"MARKS_OBTAINED":"MARKS"})
df.columns
# Out:
# Index(['NAME', 'MARKS', 'HEIGHT', 'JOB', 'CODING', 'PLAY', 'SALARY', 'COUNTRY',
#        'LANGUAGES', 'AGE', 'Height', 'RESULT', 'DOUBLE_AGE', 'AGE_CATAGORY',
#        'EMAIL'],
#       dtype='object')

# %%
df
# Out:
#           NAME  MARKS  HEIGHT             JOB CODING PLAY     SALARY  \
# 0          Ram     96     176        youtuber     NO   NO    13000.0
# 1       Arunan     97     171        Robotics    Yes  Yes   120000.0
# 2  Ambalavanan     92     174  Data Scientist    Yes   NO   130000.0
# 3  Swaminathan     94     173         Richman     No  Yes   999999.0
# 4        Kumar     79     176        Software    Yes   NO  1234500.0
#
#      COUNTRY  LANGUAGES  AGE  Height RESULT  DOUBLE_AGE    AGE_CATAGORY  \
# 0  Singapore    Unknown    0     0.0   PASS           0     Senior Aged
# 1        USA  Python,C#    0     0.0   PASS           0  Senior Citizen
# 2         UK       Java   33   173.0   FAIL          66  Senior Citizen
# 3         UK    Unknown    5     0.0   PASS          10     Senior Aged
# 4      India     Python    0     0.0   FAIL           0     Middle-Aged
#
#                    EMAIL
# 0          ram@gmail.com
# 1       arunan@gmail.com
# 2  ambalavanan@gmail.com
# ...

# %%
df.set_index("NAME",inplace=True)

# %%
df
# Out:
#              MARKS  HEIGHT             JOB CODING PLAY     SALARY    COUNTRY  \
# NAME
# Ram             96     176        youtuber     NO   NO    13000.0  Singapore
# Arunan          97     171        Robotics    Yes  Yes   120000.0        USA
# Ambalavanan     92     174  Data Scientist    Yes   NO   130000.0         UK
# Swaminathan     94     173         Richman     No  Yes   999999.0         UK
# Kumar           79     176        Software    Yes   NO  1234500.0      India
#
#              LANGUAGES  AGE  Height RESULT  DOUBLE_AGE    AGE_CATAGORY  \
# NAME
# Ram            Unknown    0     0.0   PASS           0     Senior Aged
# Arunan       Python,C#    0     0.0   PASS           0  Senior Citizen
# Ambalavanan       Java   33   173.0   FAIL          66  Senior Citizen
# Swaminathan    Unknown    5     0.0   PASS          10     Senior Aged
# Kumar           Python    0     0.0   FAIL           0     Middle-Aged
#
#                              EMAIL
# NAME
# ...

# %%
def email_upper(email):
    return email.upper()
df["EMAIL"] = df["EMAIL"].apply(email_upper)
df
# Out:
#              MARKS  HEIGHT             JOB CODING PLAY     SALARY    COUNTRY  \
# NAME
# Ram             96     176        youtuber     NO   NO    13000.0  Singapore
# Arunan          97     171        Robotics    Yes  Yes   120000.0        USA
# Ambalavanan     92     174  Data Scientist    Yes   NO   130000.0         UK
# Swaminathan     94     173         Richman     No  Yes   999999.0         UK
# Kumar           79     176        Software    Yes   NO  1234500.0      India
#
#              LANGUAGES  AGE  Height RESULT  DOUBLE_AGE    AGE_CATAGORY  \
# NAME
# Ram            Unknown    0     0.0   PASS           0     Senior Aged
# Arunan       Python,C#    0     0.0   PASS           0  Senior Citizen
# Ambalavanan       Java   33   173.0   FAIL          66  Senior Citizen
# Swaminathan    Unknown    5     0.0   PASS          10     Senior Aged
# Kumar           Python    0     0.0   FAIL           0     Middle-Aged
#
#                              EMAIL
# NAME
# ...

# %%
#create a lambda function to convert uppercase to lowercase for the df["EMAIL"]
df["EMAIL"] = df["EMAIL"].apply(lambda x: x.lower())

# %%
df
# Out:
#              MARKS  HEIGHT             JOB CODING PLAY     SALARY    COUNTRY  \
# NAME
# Ram             96     176        youtuber     NO   NO    13000.0  Singapore
# Arunan          97     171        Robotics    Yes  Yes   120000.0        USA
# Ambalavanan     92     174  Data Scientist    Yes   NO   130000.0         UK
# Swaminathan     94     173         Richman     No  Yes   999999.0         UK
# Kumar           79     176        Software    Yes   NO  1234500.0      India
#
#              LANGUAGES  AGE  Height RESULT  DOUBLE_AGE    AGE_CATAGORY  \
# NAME
# Ram            Unknown    0     0.0   PASS           0     Senior Aged
# Arunan       Python,C#    0     0.0   PASS           0  Senior Citizen
# Ambalavanan       Java   33   173.0   FAIL          66  Senior Citizen
# Swaminathan    Unknown    5     0.0   PASS          10     Senior Aged
# Kumar           Python    0     0.0   FAIL           0     Middle-Aged
#
#                              EMAIL
# NAME
# ...

# %%
df.columns
# Out:
# Index(['MARKS', 'HEIGHT', 'JOB', 'CODING', 'PLAY', 'SALARY', 'COUNTRY',
#        'LANGUAGES', 'AGE', 'Height', 'RESULT', 'DOUBLE_AGE', 'AGE_CATAGORY',
#        'EMAIL'],
#       dtype='object')

# %%
df.reset_index(inplace=True)

# %%
df.columns
# Out:
# Index(['NAME', 'MARKS', 'HEIGHT', 'JOB', 'CODING', 'PLAY', 'SALARY', 'COUNTRY',
#        'LANGUAGES', 'AGE', 'Height', 'RESULT', 'DOUBLE_AGE', 'AGE_CATAGORY',
#        'EMAIL'],
#       dtype='object')

# %%
df[["NAME","EMAIL"]]
# Out:
#           NAME                  EMAIL
# 0          Ram          ram@gmail.com
# 1       Arunan       arunan@gmail.com
# 2  Ambalavanan  ambalavanan@gmail.com
# 3  Swaminathan  swaminathan@gmail.com
# 4        Kumar        kumar@gmail.com

# %%
df
# Out:
#           NAME  MARKS  HEIGHT             JOB CODING PLAY     SALARY  \
# 0          Ram     96     176        youtuber     NO   NO    13000.0
# 1       Arunan     97     171        Robotics    Yes  Yes   120000.0
# 2  Ambalavanan     92     174  Data Scientist    Yes   NO   130000.0
# 3  Swaminathan     94     173         Richman     No  Yes   999999.0
# 4        Kumar     79     176        Software    Yes   NO  1234500.0
#
#      COUNTRY  LANGUAGES  AGE  Height RESULT  DOUBLE_AGE    AGE_CATAGORY  \
# 0  Singapore    Unknown    0     0.0   PASS           0     Senior Aged
# 1        USA  Python,C#    0     0.0   PASS           0  Senior Citizen
# 2         UK       Java   33   173.0   FAIL          66  Senior Citizen
# 3         UK    Unknown    5     0.0   PASS          10     Senior Aged
# 4      India     Python    0     0.0   FAIL           0     Middle-Aged
#
#                    EMAIL
# 0          ram@gmail.com
# 1       arunan@gmail.com
# 2  ambalavanan@gmail.com
# ...

# %%
df.set_index("NAME",inplace=True)

# %%
df
# Out:
#              MARKS  HEIGHT             JOB CODING PLAY     SALARY    COUNTRY  \
# NAME
# Ram             96     176        youtuber     NO   NO    13000.0  Singapore
# Arunan          97     171        Robotics    Yes  Yes   120000.0        USA
# Ambalavanan     92     174  Data Scientist    Yes   NO   130000.0         UK
# Swaminathan     94     173         Richman     No  Yes   999999.0         UK
# Kumar           79     176        Software    Yes   NO  1234500.0      India
#
#              LANGUAGES  AGE  Height RESULT  DOUBLE_AGE    AGE_CATAGORY  \
# NAME
# Ram            Unknown    0     0.0   PASS           0     Senior Aged
# Arunan       Python,C#    0     0.0   PASS           0  Senior Citizen
# Ambalavanan       Java   33   173.0   FAIL          66  Senior Citizen
# Swaminathan    Unknown    5     0.0   PASS          10     Senior Aged
# Kumar           Python    0     0.0   FAIL           0     Middle-Aged
#
#                              EMAIL
# NAME
# ...

# %%
df.apply(pd.Series.min)
# Out:
# MARKS                              79
# HEIGHT                            171
# JOB                    Data Scientist
# CODING                             NO
# PLAY                               NO
# SALARY                        13000.0
# COUNTRY                         India
# LANGUAGES                        Java
# AGE                                 0
# Height                            0.0
# RESULT                           FAIL
# DOUBLE_AGE                          0
# AGE_CATAGORY              Middle-Aged
# EMAIL           ambalavanan@gmail.com
# dtype: object

# %%
min1 = pd.Series.min(df["MARKS"])
min1
# Out:
# np.int64(79)

# %% [markdown]
# #
# # Sample data
# data = {'A': [10, 20, 30], 'B': [15, 25, 35], 'C': [5, 50, 100]}
# df = pd.DataFrame(data)
#
# # Custom function to increase values greater than 20 by 10
# def adjust_values(x):
#     return x + 10 if x > 20 else x
#
# # Apply the custom function to the entire DataFrame
# df_adjusted = df.applymap(adjust_values)
#
# print(df_adjusted)
# df_adjusted

# %%
def pass_fail(x):
    return x-30 if x > 75 else x
df["MARKS"] = df["MARKS"].map(pass_fail)
df
# Out:
#              MARKS  HEIGHT             JOB CODING PLAY     SALARY    COUNTRY  \
# NAME
# Ram             66     176        youtuber     NO   NO    13000.0  Singapore
# Arunan          67     171        Robotics    Yes  Yes   120000.0        USA
# Ambalavanan     62     174  Data Scientist    Yes   NO   130000.0         UK
# Swaminathan     64     173         Richman     No  Yes   999999.0         UK
# Kumar           49     176        Software    Yes   NO  1234500.0      India
#
#              LANGUAGES  AGE  Height RESULT  DOUBLE_AGE    AGE_CATAGORY  \
# NAME
# Ram            Unknown    0     0.0   PASS           0     Senior Aged
# Arunan       Python,C#    0     0.0   PASS           0  Senior Citizen
# Ambalavanan       Java   33   173.0   FAIL          66  Senior Citizen
# Swaminathan    Unknown    5     0.0   PASS          10     Senior Aged
# Kumar           Python    0     0.0   FAIL           0     Middle-Aged
#
#                              EMAIL
# NAME
# ...

# %%
df.reset_index(inplace=True)

# %%
df
# Out:
#           NAME  MARKS  HEIGHT             JOB CODING PLAY     SALARY  \
# 0          Ram     66     176        youtuber     NO   NO    13000.0
# 1       Arunan     67     171        Robotics    Yes  Yes   120000.0
# 2  Ambalavanan     62     174  Data Scientist    Yes   NO   130000.0
# 3  Swaminathan     64     173         Richman     No  Yes   999999.0
# 4        Kumar     49     176        Software    Yes   NO  1234500.0
#
#      COUNTRY  LANGUAGES  AGE  Height RESULT  DOUBLE_AGE    AGE_CATAGORY  \
# 0  Singapore    Unknown    0     0.0   PASS           0     Senior Aged
# 1        USA  Python,C#    0     0.0   PASS           0  Senior Citizen
# 2         UK       Java   33   173.0   FAIL          66  Senior Citizen
# 3         UK    Unknown    5     0.0   PASS          10     Senior Aged
# 4      India     Python    0     0.0   FAIL           0     Middle-Aged
#
#                    EMAIL
# 0          ram@gmail.com
# 1       arunan@gmail.com
# 2  ambalavanan@gmail.com
# ...

# %%
df.to_csv("Updating_Rows_Columns.csv", index=False)
