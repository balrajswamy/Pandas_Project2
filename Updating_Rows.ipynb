# %%
import pandas as pd

print("Hello world")
# Out:
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.1.2 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "C:\CondaPython\Lib\site-packages\ipykernel_launcher.py", line 17, in <module>
#     app.launch_new_instance()
#   File "C:\CondaPython\Lib\site-packages\traitlets\config\application.py", line 1075, in launch_instance
#     app.start()
#   File "C:\CondaPython\Lib\site-packages\ipykernel\kernelapp.py", line 701, in start
#     self.io_loop.start()
# ...

# %%
filename = r"C:\Users\Balraj\balraj_proj\Learning_Pandas\Update_columns.csv"
df = pd.read_csv(filename)
df
# Out:
#         NAME  MARKS_OBTAINED  HEIGHT             JOB CODING PLAY     SALARY  \
# 0     kishan              96     176        youtuber     NO   NO        NaN
# 1  Aravindan              97     171        Robotics    Yes  YES   120000.0
# 2     Mahesh              92     174  Data Scientist    Yes   NO   130000.0
# 3   Santhosh              94     173         Richman     No  Yes   999999.0
# 4   Sarvesha              79     176        Software    Yes   NO  1234500.0
#
#   COUNTRY  LANGUAGES  AGE  Height RESULT  DOUBLE_AGE    AGE_CATAGORY
# 0   China        NaN    0     NaN   PASS           0     Senior Aged
# 1     USA  Python,C#    0     NaN   PASS           0  Senior Citizen
# 2      UK       Java   33   173.0   FAIL          66  Senior Citizen
# 3      UK        NaN    5     NaN   PASS          10     Senior Aged
# 4   India     Python    0     NaN   FAIL           0     Middle-Aged

# %%
df.loc[0]
# Out:
# NAME                   kishan
# MARKS_OBTAINED             96
# HEIGHT                    176
# JOB                  youtuber
# CODING                     NO
# PLAY                       NO
# SALARY                    NaN
# COUNTRY                 China
# LANGUAGES                 NaN
# AGE                         0
# Height                    NaN
# RESULT                   PASS
# DOUBLE_AGE                  0
# AGE_CATAGORY      Senior Aged
# Name: 0, dtype: object

# %%
df.loc[0,"COUNTRY"]= "ROMANIA"

# %%
df.loc[0,["SALARY","COUNTRY"]]=[13000,"Singapore"]

# %%
df
# Out:
#         NAME  MARKS_OBTAINED  HEIGHT             JOB CODING PLAY     SALARY  \
# 0     kishan              96     176        youtuber     NO   NO    13000.0
# 1  Aravindan              97     171        Robotics    Yes  YES   120000.0
# 2     Mahesh              92     174  Data Scientist    Yes   NO   130000.0
# 3   Santhosh              94     173         Richman     No  Yes   999999.0
# 4   Sarvesha              79     176        Software    Yes   NO  1234500.0
#
#      COUNTRY  LANGUAGES  AGE  Height RESULT  DOUBLE_AGE    AGE_CATAGORY
# 0  Singapore        NaN    0     NaN   PASS           0     Senior Aged
# 1        USA  Python,C#    0     NaN   PASS           0  Senior Citizen
# 2         UK       Java   33   173.0   FAIL          66  Senior Citizen
# 3         UK        NaN    5     NaN   PASS          10     Senior Aged
# 4      India     Python    0     NaN   FAIL           0     Middle-Aged

# %%
df.loc[1,"PLAY"] = "Yes"
df[(df["PLAY"]=="Yes") & df["SALARY"]==12000]
#filter1 = (df["PLAY"]=="Yes")
#df[filter1]
# Out:
# Empty DataFrame
# Columns: [NAME, MARKS_OBTAINED, HEIGHT, JOB, CODING, PLAY, SALARY, COUNTRY, LANGUAGES, AGE, Height, RESULT, DOUBLE_AGE, AGE_CATAGORY]
# Index: []

# %%
filter1 = (df["PLAY"]=="Yes")
filter1
# Out:
# 0    False
# 1     True
# 2    False
# 3     True
# 4    False
# Name: PLAY, dtype: bool

# %%
df[filter1]["SALARY"]
# Out:
# 1    120000.0
# 3    999999.0
# Name: SALARY, dtype: float64

# %%
df2 = df.loc[filter1,["JOB","NAME","SALARY"]]

type(df2)
# Out:
# pandas.core.frame.DataFrame

# %%
df2.head(2)
# Out:
#         JOB       NAME    SALARY
# 1  Robotics  Aravindan  120000.0
# 3   Richman   Santhosh  999999.0

# %%
df.to_csv("rows_update.csv", index=False)

# %%
df
# Out:
#         NAME  MARKS_OBTAINED  HEIGHT             JOB CODING PLAY     SALARY  \
# 0     kishan              96     176        youtuber     NO   NO    13000.0
# 1  Aravindan              97     171        Robotics    Yes  Yes   120000.0
# 2     Mahesh              92     174  Data Scientist    Yes   NO   130000.0
# 3   Santhosh              94     173         Richman     No  Yes   999999.0
# 4   Sarvesha              79     176        Software    Yes   NO  1234500.0
#
#      COUNTRY  LANGUAGES  AGE  Height RESULT  DOUBLE_AGE    AGE_CATAGORY
# 0  Singapore        NaN    0     NaN   PASS           0     Senior Aged
# 1        USA  Python,C#    0     NaN   PASS           0  Senior Citizen
# 2         UK       Java   33   173.0   FAIL          66  Senior Citizen
# 3         UK        NaN    5     NaN   PASS          10     Senior Aged
# 4      India     Python    0     NaN   FAIL           0     Middle-Aged

# %%
df.loc[df["NAME"]=="Sarvesha","NAME"]= "Kumar"

# %%
df
# Out:
#         NAME  MARKS_OBTAINED  HEIGHT             JOB CODING PLAY     SALARY  \
# 0     kishan              96     176        youtuber     NO   NO    13000.0
# 1  Aravindan              97     171        Robotics    Yes  Yes   120000.0
# 2     Mahesh              92     174  Data Scientist    Yes   NO   130000.0
# 3   Santhosh              94     173         Richman     No  Yes   999999.0
# 4      Kumar              79     176        Software    Yes   NO  1234500.0
#
#      COUNTRY  LANGUAGES  AGE  Height RESULT  DOUBLE_AGE    AGE_CATAGORY
# 0  Singapore        NaN    0     NaN   PASS           0     Senior Aged
# 1        USA  Python,C#    0     NaN   PASS           0  Senior Citizen
# 2         UK       Java   33   173.0   FAIL          66  Senior Citizen
# 3         UK        NaN    5     NaN   PASS          10     Senior Aged
# 4      India     Python    0     NaN   FAIL           0     Middle-Aged

# %%
df.loc[df["NAME"]=="Kishan","NAME"]= "Ram"

# %%
df
# Out:
#         NAME  MARKS_OBTAINED  HEIGHT             JOB CODING PLAY     SALARY  \
# 0     kishan              96     176        youtuber     NO   NO    13000.0
# 1  Aravindan              97     171        Robotics    Yes  Yes   120000.0
# 2     Mahesh              92     174  Data Scientist    Yes   NO   130000.0
# 3   Santhosh              94     173         Richman     No  Yes   999999.0
# 4      Kumar              79     176        Software    Yes   NO  1234500.0
#
#      COUNTRY  LANGUAGES  AGE  Height RESULT  DOUBLE_AGE    AGE_CATAGORY
# 0  Singapore        NaN    0     NaN   PASS           0     Senior Aged
# 1        USA  Python,C#    0     NaN   PASS           0  Senior Citizen
# 2         UK       Java   33   173.0   FAIL          66  Senior Citizen
# 3         UK        NaN    5     NaN   PASS          10     Senior Aged
# 4      India     Python    0     NaN   FAIL           0     Middle-Aged

# %%
df
# Out:
#         NAME  MARKS_OBTAINED  HEIGHT             JOB CODING PLAY     SALARY  \
# 0     kishan              96     176        youtuber     NO   NO    13000.0
# 1  Aravindan              97     171        Robotics    Yes  Yes   120000.0
# 2     Mahesh              92     174  Data Scientist    Yes   NO   130000.0
# 3   Santhosh              94     173         Richman     No  Yes   999999.0
# 4      Kumar              79     176        Software    Yes   NO  1234500.0
#
#      COUNTRY  LANGUAGES  AGE  Height RESULT  DOUBLE_AGE    AGE_CATAGORY
# 0  Singapore        NaN    0     NaN   PASS           0     Senior Aged
# 1        USA  Python,C#    0     NaN   PASS           0  Senior Citizen
# 2         UK       Java   33   173.0   FAIL          66  Senior Citizen
# 3         UK        NaN    5     NaN   PASS          10     Senior Aged
# 4      India     Python    0     NaN   FAIL           0     Middle-Aged

# %%
df.loc[df["NAME"]=="Kishan","NAME"]= "Ram"

# %%
df.loc[0,"NAME"] = "Ram"

# %%
df
# Out:
#         NAME  MARKS_OBTAINED  HEIGHT             JOB CODING PLAY     SALARY  \
# 0        Ram              96     176        youtuber     NO   NO    13000.0
# 1  Aravindan              97     171        Robotics    Yes  Yes   120000.0
# 2     Mahesh              92     174  Data Scientist    Yes   NO   130000.0
# 3   Santhosh              94     173         Richman     No  Yes   999999.0
# 4      Kumar              79     176        Software    Yes   NO  1234500.0
#
#      COUNTRY  LANGUAGES  AGE  Height RESULT  DOUBLE_AGE    AGE_CATAGORY
# 0  Singapore        NaN    0     NaN   PASS           0     Senior Aged
# 1        USA  Python,C#    0     NaN   PASS           0  Senior Citizen
# 2         UK       Java   33   173.0   FAIL          66  Senior Citizen
# 3         UK        NaN    5     NaN   PASS          10     Senior Aged
# 4      India     Python    0     NaN   FAIL           0     Middle-Aged

# %%
df.loc[1,"NAME"] = "Arunan"

# %%
df
# Out:
#        NAME  MARKS_OBTAINED  HEIGHT             JOB CODING PLAY     SALARY  \
# 0       Ram              96     176        youtuber     NO   NO    13000.0
# 1    Arunan              97     171        Robotics    Yes  Yes   120000.0
# 2    Mahesh              92     174  Data Scientist    Yes   NO   130000.0
# 3  Santhosh              94     173         Richman     No  Yes   999999.0
# 4     Kumar              79     176        Software    Yes   NO  1234500.0
#
#      COUNTRY  LANGUAGES  AGE  Height RESULT  DOUBLE_AGE    AGE_CATAGORY
# 0  Singapore        NaN    0     NaN   PASS           0     Senior Aged
# 1        USA  Python,C#    0     NaN   PASS           0  Senior Citizen
# 2         UK       Java   33   173.0   FAIL          66  Senior Citizen
# 3         UK        NaN    5     NaN   PASS          10     Senior Aged
# 4      India     Python    0     NaN   FAIL           0     Middle-Aged

# %%
df.loc[2,"NAME"] = "Ambalavanan"
df.loc[3,"NAME"] = "Swaminathan"

# %%
df
# Out:
#           NAME  MARKS_OBTAINED  HEIGHT             JOB CODING PLAY     SALARY  \
# 0          Ram              96     176        youtuber     NO   NO    13000.0
# 1       Arunan              97     171        Robotics    Yes  Yes   120000.0
# 2  Ambalavanan              92     174  Data Scientist    Yes   NO   130000.0
# 3  Swaminathan              94     173         Richman     No  Yes   999999.0
# 4        Kumar              79     176        Software    Yes   NO  1234500.0
#
#      COUNTRY  LANGUAGES  AGE  Height RESULT  DOUBLE_AGE    AGE_CATAGORY
# 0  Singapore        NaN    0     NaN   PASS           0     Senior Aged
# 1        USA  Python,C#    0     NaN   PASS           0  Senior Citizen
# 2         UK       Java   33   173.0   FAIL          66  Senior Citizen
# 3         UK        NaN    5     NaN   PASS          10     Senior Aged
# 4      India     Python    0     NaN   FAIL           0     Middle-Aged

# %%
df.to_csv("row_updates.csv", index=False)

# %%
df['LANGUAGES'] = df['LANGUAGES'].where(df['LANGUAGES'].notna(), other='Unknown')

# %%
df['Height'] = df['Height'].where(df['Height'].notna(), other=0)

# %%
df
# Out:
#           NAME  MARKS_OBTAINED  HEIGHT             JOB CODING PLAY     SALARY  \
# 0          Ram              96     176        youtuber     NO   NO    13000.0
# 1       Arunan              97     171        Robotics    Yes  Yes   120000.0
# 2  Ambalavanan              92     174  Data Scientist    Yes   NO   130000.0
# 3  Swaminathan              94     173         Richman     No  Yes   999999.0
# 4        Kumar              79     176        Software    Yes   NO  1234500.0
#
#      COUNTRY  LANGUAGES  AGE  Height RESULT  DOUBLE_AGE    AGE_CATAGORY
# 0  Singapore    Unknown    0     0.0   PASS           0     Senior Aged
# 1        USA  Python,C#    0     0.0   PASS           0  Senior Citizen
# 2         UK       Java   33   173.0   FAIL          66  Senior Citizen
# 3         UK    Unknown    5     0.0   PASS          10     Senior Aged
# 4      India     Python    0     0.0   FAIL           0     Middle-Aged

# %%
df.to_csv("row_updates.csv", index=False)
